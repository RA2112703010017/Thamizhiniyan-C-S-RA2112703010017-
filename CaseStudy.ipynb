# %% [markdown]
# Case Study on Weather report between 2006 - 2010

# %%
pip install pandas

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/weatherHistory.csv')
df
# Out:
#                       Formatted Date  ...                           Daily Summary
# 0      2006-04-01 00:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 1      2006-04-01 01:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 2      2006-04-01 02:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 3      2006-04-01 03:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 4      2006-04-01 04:00:00.000 +0200  ...       Partly cloudy throughout the day.
# ...                              ...  ...                                     ...
# 96448  2016-09-09 19:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96449  2016-09-09 20:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96450  2016-09-09 21:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96451  2016-09-09 22:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# ...

# %%
maxTem = df['Temperature (C)'].max()
maxTem
# Out:
# 39.90555556

# %%
minTem = df['Temperature (C)'].min()
minTem
# Out:
# -21.82222222

# %%
df['Temperature (C)'].mean()
# Out:
# 11.932678437519867

# %%
df['Formatted Date'][df['Temperature (C)']== maxTem]
# Out:
# 12759    2007-07-22 15:00:00.000 +0200
# Name: Formatted Date, dtype: object

# %%
df['Formatted Date'][df['Temperature (C)'] == minTem]
# Out:
# 54847    2012-02-10 07:00:00.000 +0100
# Name: Formatted Date, dtype: object

# %%
maxwin = df['Wind Speed (km/h)'].max()
maxwin
# Out:
# 63.8526

# %%
minwin = df['Wind Speed (km/h)'].min()
minwin
# Out:
# 0.0

# %%
df['Formatted Date'][df['Wind Speed (km/h)'] == maxwin]
# Out:
# 12181    2007-01-29 13:00:00.000 +0100
# Name: Formatted Date, dtype: object

# %%
df['Wind Speed (km/h)'].mean()
# Out:
# 10.810640140793208

# %%
df['Summary'].max()
# Out:
# 'Windy and Partly Cloudy'

# %%
df['Daily Summary'].max()
# Out:
# 'Windy in the afternoon.'

# %%
df['Humidity'].max()
# Out:
# 1.0

# %%
df['Humidity'].min()
# Out:
# 0.0

# %%
df['Humidity'].mean()
# Out:
# 0.7348989663358906

# %%
OverallComparison = df.describe(include='all')
OverallComparison
# Out:
#                        Formatted Date  ...                      Daily Summary
# count                           96453  ...                              96453
# unique                          96429  ...                                214
# top     2010-08-02 12:00:00.000 +0200  ...  Mostly cloudy throughout the day.
# freq                                2  ...                              20085
# mean                              NaN  ...                                NaN
# std                               NaN  ...                                NaN
# min                               NaN  ...                                NaN
# 25%                               NaN  ...                                NaN
# 50%                               NaN  ...                                NaN
# 75%                               NaN  ...                                NaN
# max                               NaN  ...                                NaN
#
# [11 rows x 12 columns]

# %% [markdown]
# The maximum Temperature recorded in this time period is 39.90555556 C on 2007-07-22

# %% [markdown]
# The minimum Temperature recorded in this time period is -21.82222222 C on 2012-02-10

# %% [markdown]
# The average Temperature recorded in this time interval is 11.932678437519867 C

# %% [markdown]
# The maximum WindSpeed recorded in this time period is 63.8526 km/h on 2007-01-29

# %% [markdown]
# The minimum windspeed recorded in this time period is 0.0 km/h

# %% [markdown]
# The average windspeed recorded in this time period is 10.810640140793208 km/h

# %% [markdown]
# In this time period the weather was mostly Windy and Partly Cloudy

# %% [markdown]
# In this time period the average weather on a Daily Basis was  Windy in the afternoon

# %% [markdown]
# The maximum Humidity recorded in this time period is 1.0

# %% [markdown]
# The minimum Humidity recorded in this time period is 0.0

# %% [markdown]
# The average Humitdity Recorded in this time period is 0.7348989663358906
